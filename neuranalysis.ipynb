# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import axes3d

# %matplotlib inline

# %%
voxels = np.load('1_0001Full100_res50.npy')

df = pd.DataFrame(voxels, columns=['x', 'y', 'z'])
df['distance'] = np.sqrt(df['x']**2 + df['y']**2 + df['z']**2)
fig = plt.figure(figsize=(12, 9))
ax = fig.add_subplot(111, projection='3d')
ax.scatter3D(df['x'], df['y'], df['z'], c=df['distance'], cmap='viridis')
print('N = {}'.format(len(voxels)))
# Out:
# N = 1475

# %%
voxels = np.load('1_0001Full100_res500.npy')

df = pd.DataFrame(voxels, columns=['x', 'y', 'z'])
df['distance'] = np.sqrt(df['x']**2 + df['y']**2 + df['z']**2)
fig = plt.figure(figsize=(12, 9))
ax = fig.add_subplot(111, projection='3d')
ax.scatter3D(df['x'], df['y'], df['z'], c=df['distance'], cmap='viridis')
print('N = {}'.format(len(voxels)))
# Out:
# N = 117130
